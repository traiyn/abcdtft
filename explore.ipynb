# %%
import json
import pandas as pd
import os

# %%
data_path = "C:\\source\\abcdtft\\data\\Traiyn\\"

# %%
filepath = os.path.join(data_path, 'NA1_3324424746.json')
with open(filepath) as f:
    data = json.load(f)
    
print(data)
# Out:
# {'metadata': {'data_version': '4', 'match_id': 'NA1_3324424746', 'participants': ['rMm51F3Ma8pkoME-TdELfVs-uBHNLgTQfpNjEEr7KIwF816Mn_aAIPi0x4hM39B3VMEgo-dyZyJ7ew', 'M-E2jbJ3yqkTqueGSoWDHcTKKoo--jhNBhpCHsTFMsSGjxdvMcZvelyASvQMEqdcDaOrMG2bPrybJA', 'BBm_WQwF_HE6PAxtZk4nhKWAAdHJlWbNeD5aqIOskfo2Hw4_YfVKtgUXyUXzLBXK-M0e924SK1rSAw', 'KJX-SXmKkrKlHvcpaEArDlNgLQcHZwsHhu-_8c0vJxNqtj6zeGgLxjDfw9V2SZvI0RkjjTYQDphwtA', 'x4ZulDmVIzjh9M8vknqkDuayTqe9gmBszw04Sy89xEFa4eF-hXo7j41uWbiRXyp8dcWEeMPjiaewjQ', 'Smv1Vg7HCkcNpK-BIAkcEITgpV0Q2LJeVWG_zST144_ErnGpOc0o_TFqJTC30Nhpa981cKn7t_Q5cw', 'l-5y6lvLc5cvTzJbobDVLWBbeGl6v2nzwBhw7UFUjyHUdIx_29mVZKkCrpwBF84aAEl6V54bE1dHVA', 'SEKjnNerQuRXtbDdCIn6w8THl3X-WAZIuXv0m9dNn1gjpuIPNy_qhOOtjJd5kIsXutQC9-bH7d_yWg']}, 'info': {'game_datetime': 1584220229204, 'game_length': 2143.7216796875, 'game_version': 'Version 10.5.312.392 (Mar 06 2020/12:42:48) [PUBLIC] <Releases/10.5>', 'participants': [{'companion': {'content_ID': 'ebf6a5d5-82c6-4c49-906a-7dea5373b032', 'skin_ID': 
# ...

# %%
for participant in data['info']['participants']:
    print(participant)
# Out:
# {'companion': {'content_ID': 'ebf6a5d5-82c6-4c49-906a-7dea5373b032', 'skin_ID': 4, 'species': 'PetPenguKnight'}, 'gold_left': 1, 'last_round': 28, 'level': 7, 'placement': 6, 'players_eliminated': 0, 'puuid': 'rMm51F3Ma8pkoME-TdELfVs-uBHNLgTQfpNjEEr7KIwF816Mn_aAIPi0x4hM39B3VMEgo-dyZyJ7ew', 'time_eliminated': 1636.5467529296875, 'total_damage_to_players': 56, 'traits': [{'name': 'Berserker', 'num_units': 1, 'style': 0, 'tier_current': 0, 'tier_total': 2}, {'name': 'Celestial', 'num_units': 1, 'style': 0, 'tier_current': 0, 'tier_total': 1}, {'name': 'Inferno', 'num_units': 1, 'style': 0, 'tier_current': 0, 'tier_total': 3}, {'name': 'Light', 'num_units': 1, 'style': 0, 'tier_current': 0, 'tier_total': 3}, {'name': 'Mage', 'num_units': 1, 'style': 0, 'tier_current': 0, 'tier_total': 2}, {'name': 'Set2_Ranger', 'num_units': 1, 'style': 0, 'tier_current': 0, 'tier_total': 3}, {'name': 'Shadow', 'num_units': 5, 'style': 1, 'tier_current': 1, 'tier_total': 2}, {'name': 'Soulbound', 'num_un
# ...

# %%
matches = os.listdir(data_path)
for match in matches:
    filepath = os.path.join(data_path, match)
    with open(filepath) as f:
        data = json.load(f)
